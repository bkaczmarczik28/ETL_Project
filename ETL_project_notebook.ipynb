# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# %% [markdown]
# # Extract CSV files into a dataframe

# %%
csv_airbnb = "Resources/AB_NYC_2019.csv"
airbnb_df = pd.read_csv(csv_airbnb)
airbnb_df.head()

# %%
csv_properties = "Resources/nyc-rolling-sales.csv"
nycprops_df = pd.read_csv(csv_properties)
nycprops_df.head()
# Out:
#    Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0           4        1  ALPHABET CITY
# 1           5        1  ALPHABET CITY
# 2           6        1  ALPHABET CITY
# 3           7        1  ALPHABET CITY
# 4           8        1  ALPHABET CITY
#
#                        BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  07 RENTALS - WALKUP APARTMENTS                                2A    392
# 1  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 2  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 3  07 RENTALS - WALKUP APARTMENTS                                2B    402
# 4  07 RENTALS - WALKUP APARTMENTS                                2A    404
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  ...  \
# 0    6                                  C2            153 AVENUE B  ...
# 1   26                                  C7   234 EAST 4TH   STREET  ...
# ...

# %% [markdown]
# # Transform AirBNB DataFrame

# %%
airbnb_cols = ["id","neighbourhood_group", "neighbourhood", "latitude", "longitude", "room_type", "price", "number_of_reviews", "calculated_host_listings_count"]
airbnb_transformed= airbnb_df[airbnb_cols].copy()
airbnb_transformed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-95fea9cf5fa2> in <module>
#       1 airbnb_cols = ["id","neighbourhood_group", "neighbourhood", "latitude", "longitude", "room_type", "price", "number_of_reviews", "calculated_host_listings_count"]
# ----> 2 airbnb_transformed= airbnb_df[airbnb_cols].copy()
#       3 airbnb_transformed
#
# NameError: name 'airbnb_df' is not defined

# %%
airbnb_transformed = airbnb_transformed.rename(columns={"calculated_host_listings_count": "listings_per_host",
                                                        "id":"airbnb_id",
                                                        "price":"price_$"
                                                       })
airbnb_transformed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-1cce011dbc5d> in <module>
# ----> 1 airbnb_transformed = airbnb_transformed.rename(columns={"calculated_host_listings_count": "listings_per_host",
#       2                                                         "id":"airbnb_id",
#       3                                                         "price":"price_$"
#       4                                                        })
#       5 airbnb_transformed
#
# NameError: name 'airbnb_transformed' is not defined

# %%
#drop duplicates
airbnb_transformed.drop_duplicates("airbnb_id", inplace=True)
airbnb_transformed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-74dc7c4dc7c7> in <module>
#       1 #drop duplicates
# ----> 2 airbnb_transformed.drop_duplicates("airbnb_id", inplace=True)
#       3 airbnb_transformed
#
# NameError: name 'airbnb_transformed' is not defined

# %%
# Set index
airbnb_transformed.set_index("airbnb_id", inplace=True)

airbnb_transformed.head()

# %% [markdown]
# # Transform NYC Property Dataframe

# %%
nycprops_cols=['NEIGHBORHOOD','BUILDING CLASS CATEGORY','BLOCK','LOT', 'ADDRESS', 'ZIP CODE', 'TOTAL UNITS', 'GROSS SQUARE FEET', 'SALE PRICE', 'SALE DATE']
nycprops_transformed= nycprops_df[nycprops_cols].copy()
nycprops_transformed.head()
# Out:
#     NEIGHBORHOOD                      BUILDING CLASS CATEGORY  BLOCK  LOT  \
# 0  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS                 392    6
# 1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS                 399   26
# 2  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS                 399   39
# 3  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS                 402   21
# 4  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS                 404   55
#
#                   ADDRESS  ZIP CODE  TOTAL UNITS GROSS SQUARE FEET SALE PRICE  \
# 0            153 AVENUE B     10009            5              6440    6625000
# 1   234 EAST 4TH   STREET     10009           31             18690        -
# 2   197 EAST 3RD   STREET     10009           17              7803        -
# 3     154 EAST 7TH STREET     10009           10              6794    3936272
# 4  301 EAST 10TH   STREET     10009            6              4615    8000000
#
#              SALE DATE
# 0  2017-07-19 00:00:00
# ...

# %%
nycprops_transformed = nycprops_transformed.rename(columns={"NEIGHBORHOOD": "neighborhood",
                                                            "BUILDING CLASS CATEGORY" :"building_class_category",
                                                            "BLOCK":"block",
                                                            "LOT" : "lot",
                                                            "ADDRESS":"address",
                                                            "ZIP CODE":"zip_code",
                                                            "TOTAL UNITS":"total_units",
                                                            "GROSS SQUARE FEET":"gross_sq_feet",
                                                            "SALE PRICE":"sale_price_$",
                                                            "SALE DATE":"sale_date"
                                                       })
nycprops_transformed.head()
# Out:
#     neighborhood                      building_class_category  block  lot  \
# 0  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS                 392    6
# 1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS                 399   26
# 2  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS                 399   39
# 3  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS                 402   21
# 4  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS                 404   55
#
#                   address  zip_code  total_units gross_sq_feet sale_price_$  \
# 0            153 AVENUE B     10009            5          6440      6625000
# 1   234 EAST 4TH   STREET     10009           31         18690          -
# 2   197 EAST 3RD   STREET     10009           17          7803          -
# 3     154 EAST 7TH STREET     10009           10          6794      3936272
# 4  301 EAST 10TH   STREET     10009            6          4615      8000000
#
#              sale_date
# 0  2017-07-19 00:00:00
# ...

# %%
# reformat sales date to just include the date
new = nycprops_transformed["sale_date"].str.split(" ", n = 1, expand = True) 
new.head()
# Out:
#             0         1
# 0  2017-07-19  00:00:00
# 1  2016-12-14  00:00:00
# 2  2016-12-09  00:00:00
# 3  2016-09-23  00:00:00
# 4  2016-11-17  00:00:00

# %%
nycprops_transformed['sale_date']=new[0]
nycprops_transformed.head()
# Out:
#     neighborhood                      building_class_category  block  lot  \
# 0  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS                 392    6
# 1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS                 399   26
# 2  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS                 399   39
# 3  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS                 402   21
# 4  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS                 404   55
#
#                   address  zip_code  total_units gross_sq_feet sale_price_$  \
# 0            153 AVENUE B     10009            5          6440      6625000
# 1   234 EAST 4TH   STREET     10009           31         18690          -
# 2   197 EAST 3RD   STREET     10009           17          7803          -
# 3     154 EAST 7TH STREET     10009           10          6794      3936272
# 4  301 EAST 10TH   STREET     10009            6          4615      8000000
#
#     sale_date
# 0  2017-07-19
# 1  2016-12-14
# 2  2016-12-09
# ...

# %%
#check size of dataframe
nycprops_transformed.size
# Out:
# 845480

# %%
#drop any listings without a sales price
nycprops_transformed.dropna(subset=['sale_price_$'])
nycprops_transformed.size
# Out:
# 845480

# %%
#replace empty cells with - with 
nycprops_transformed.dtypes
# Out:
# neighborhood               object
# building_class_category    object
# block                       int64
# lot                         int64
# address                    object
# zip_code                    int64
# total_units                 int64
# gross_sq_feet              object
# sale_price_$               object
# sale_date                  object
# dtype: object

# %%
#identify and save the - character in the columns intended to be for integers
character=nycprops_transformed.iloc[1, 8]
character
# Out:
# ' -  '

# %%
#eliminate - character in any cells so integer columns only have integers in them
nycprops_transformed=nycprops_transformed.replace(character, np.nan)
nycprops_transformed.head()
# Out:
#     neighborhood                      building_class_category  block  lot  \
# 0  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS                 392    6
# 1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS                 399   26
# 2  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS                 399   39
# 3  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS                 402   21
# 4  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS                 404   55
#
#                   address  zip_code  total_units gross_sq_feet sale_price_$  \
# 0            153 AVENUE B     10009            5          6440      6625000
# 1   234 EAST 4TH   STREET     10009           31         18690          NaN
# 2   197 EAST 3RD   STREET     10009           17          7803          NaN
# 3     154 EAST 7TH STREET     10009           10          6794      3936272
# 4  301 EAST 10TH   STREET     10009            6          4615      8000000
#
#     sale_date
# 0  2017-07-19
# 1  2016-12-14
# 2  2016-12-09
# ...

# %% [markdown]
# # Create database connection

# %%
connection_string = "postgres:Printshop1@localhost:5432/nyc_airbnb"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['airbnb', 'property']

# %% [markdown]
# # Load Dataframes into SQL database

# %%
nycprops_transformed.to_sql(name='property', con=engine, if_exists='append', index=True)

# %%
airbnb_transformed.to_sql(name='airbnb', con=engine, if_exists='append', index=True)
